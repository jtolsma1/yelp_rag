# %%
import sys
current_dir = "/Users/josephtolsma/Documents/dev/yelp_rag"
sys.path.insert(0,current_dir)

# %%
from src import config
from src.data_io import ImportYelpReviewText

# %%
io = ImportYelpReviewText(config.DATA_DIR_RAW,config.DATA_DIR_SAMP)
review_df = io.generate_final_restaurant_list_for_rag()
# Out:
# Sampling Yelp datasets...
# Yelp dataset sample with shape (464172, 22) created.
# Yelp dataset sample stored as 'reviews_sample.csv' at /Users/josephtolsma/Documents/dev/yelp_rag/data/sampled
# Sampling Yelp dataset for 10 restaurants to use in this RAG demo.
# RAG dataset consisting of 10 and with shape (2466, 22) created.
# RAG dataset sample stored as 'reviews_df.csv' at /Users/josephtolsma/Documents/dev/yelp_rag/data/sampled
